# %% [markdown]
# <a href="https://colab.research.google.com/github/Qaiserfarooq285/Labtasks/blob/main/actualvscounterfactual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Required **Packages**

# %%
# !pip install highway-env stable-baselines3[extra] --quiet

# %% [markdown]
# # **imports**

# %%
import gymnasium as gym
import highway_env
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
import os
from PIL import Image
from IPython.display import display, Image as IPImage

# %% [markdown]
# # **Environment Configuration**

# %%
config = {
    "lanes_count": 4,
    "vehicles_count": 30,
    "duration": 40,
    "other_vehicles_type": "highway_env.vehicle.behavior.IDMVehicle",
    "screen_width": 600,
    "screen_height": 150,
    "centering_position": [0.3, 0.5],
    "scaling": 5.5,
    "simulation_frequency": 15,
    "policy_frequency": 5,
    "render_agent": True,
    "offscreen_rendering": True
}

env = gym.make("highway-v0", render_mode="rgb_array", config=config)
obs, _ = env.reset()

# %% [markdown]
# # **Train DQN Agent**

# %%
model = DQN(
    "MlpPolicy",
    env,
    policy_kwargs={"net_arch": [256, 256]},
    verbose=1,
    learning_rate=5e-4,
    buffer_size=10000,
    learning_starts=100,
    batch_size=32,
    gamma=0.8,
    train_freq=1,
    target_update_interval=50,
)

model.learn(total_timesteps=10000)
model.save("dqn_highway_model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | 30       |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 14       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 152      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.212    |
# |    n_updates        | 51       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.4     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 16       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 267      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0588   |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.7     |
# |    ep_rew_mean      | 39.6     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 18       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 584      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.103    |
# |    n_updates        | 483      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.6     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.367    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 18       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 666      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 565      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 18       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 768      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00304  |
# |    n_updates        | 667      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 31.2     |
# |    exploration_rate | 0.151    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 19       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 894      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 793      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 19       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 1037     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00555  |
# |    n_updates        | 936      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.5     |
# |    ep_rew_mean      | 31.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 20       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 1169     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 1068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.2     |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 20       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 1340     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.232    |
# |    n_updates        | 1239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 20       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 1519     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00293  |
# |    n_updates        | 1418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 20       |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 1620     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00691  |
# |    n_updates        | 1519     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 32.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 21       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 1780     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00793  |
# |    n_updates        | 1679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.3     |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 21       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 1888     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 1787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 32.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 21       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 2061     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.126    |
# |    n_updates        | 1960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.4     |
# |    ep_rew_mean      | 32.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 21       |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 2184     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00693  |
# |    n_updates        | 2083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.9     |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 21       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 2299     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.23     |
# |    n_updates        | 2198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.9     |
# |    ep_rew_mean      | 34       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 21       |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 2574     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 2473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 33.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 21       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 2674     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00842  |
# |    n_updates        | 2573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.1     |
# |    ep_rew_mean      | 33.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 21       |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 2820     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.125    |
# |    n_updates        | 2719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.7     |
# |    ep_rew_mean      | 34.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 21       |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 3017     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.242    |
# |    n_updates        | 2916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.9     |
# |    ep_rew_mean      | 35.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 22       |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 3266     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 3165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.4     |
# |    ep_rew_mean      | 36       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 22       |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 3471     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.222    |
# |    n_updates        | 3370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | 37.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 22       |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 3748     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.115    |
# |    n_updates        | 3647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40       |
# |    ep_rew_mean      | 36.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 22       |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 3844     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00526  |
# |    n_updates        | 3743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.7     |
# |    ep_rew_mean      | 37.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 22       |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 4066     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.123    |
# |    n_updates        | 3965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.8     |
# |    ep_rew_mean      | 38.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 22       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 4329     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.123    |
# |    n_updates        | 4228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.1     |
# |    ep_rew_mean      | 40       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 22       |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 4578     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00274  |
# |    n_updates        | 4477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.6     |
# |    ep_rew_mean      | 38.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 22       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 4744     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0101   |
# |    n_updates        | 4643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42       |
# |    ep_rew_mean      | 39.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 22       |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 4866     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0184   |
# |    n_updates        | 4765     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.6     |
# |    ep_rew_mean      | 40       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 22       |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 5027     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 4926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.9     |
# |    ep_rew_mean      | 40.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 22       |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 5180     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.125    |
# |    n_updates        | 5079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44       |
# |    ep_rew_mean      | 41.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 22       |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 5440     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.127    |
# |    n_updates        | 5339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.2     |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 22       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 5691     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0121   |
# |    n_updates        | 5590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.2     |
# |    ep_rew_mean      | 42.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 22       |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 5859     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00313  |
# |    n_updates        | 5758     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.9     |
# |    ep_rew_mean      | 42.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 22       |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 6008     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 5907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.5     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 22       |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 6272     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.194    |
# |    n_updates        | 6171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.5     |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 22       |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 6429     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00841  |
# |    n_updates        | 6328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.6     |
# |    ep_rew_mean      | 45.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 22       |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 6647     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.227    |
# |    n_updates        | 6546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.9     |
# |    ep_rew_mean      | 45.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 22       |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 6847     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 6746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.3     |
# |    ep_rew_mean      | 46.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 22       |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 7114     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00372  |
# |    n_updates        | 7013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 49.4     |
# |    ep_rew_mean      | 46.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 22       |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 7235     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00537  |
# |    n_updates        | 7134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.7     |
# |    ep_rew_mean      | 46.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 22       |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 7444     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00891  |
# |    n_updates        | 7343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.2     |
# |    ep_rew_mean      | 48.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 22       |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 7794     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.103    |
# |    n_updates        | 7693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | 50.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 22       |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 8133     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.127    |
# |    n_updates        | 8032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.3     |
# |    ep_rew_mean      | 51.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 22       |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 8449     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 8348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.9     |
# |    ep_rew_mean      | 51       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 22       |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 8654     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00337  |
# |    n_updates        | 8553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.8     |
# |    ep_rew_mean      | 51.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 22       |
# |    time_elapsed     | 402      |
# |    total_timesteps  | 8953     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 8852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54.7     |
# |    ep_rew_mean      | 51.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 22       |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 9215     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.237    |
# |    n_updates        | 9114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.7     |
# |    ep_rew_mean      | 52.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 22       |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 9415     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 9314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 55.4     |
# |    ep_rew_mean      | 52.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 22       |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 9610     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.235    |
# |    n_updates        | 9509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.6     |
# |    ep_rew_mean      | 53.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 22       |
# |    time_elapsed     | 447      |
# |    total_timesteps  | 9990     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.126    |
# |    n_updates        | 9889     |
# ----------------------------------

# %% [markdown]
# # Generate Actual Agent Trajectory GIF

# %%
frames_actual = []
obs, _ = env.reset()
done = False
while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    frame = env.render()
    frames_actual.append(Image.fromarray(frame))

actual_gif_path = "actual_trajectory.gif"
frames_actual[0].save(
    actual_gif_path,
    save_all=True,
    append_images=frames_actual[1:],
    duration=100,
    loop=0
)
print(f"✅ Actual Agent Trajectory Saved: {actual_gif_path}")
# Out:
# ✅ Actual Agent Trajectory Saved: actual_trajectory.gif

# %% [markdown]
# # **Actual trajectory**

# %%
print("🎯 Actual Agent Trajectory:")
display(IPImage(filename=actual_gif_path))
# Out:
# 🎯 Actual Agent Trajectory:

# %%
import matplotlib.pyplot as plt

frames_actual = []
rewards = []  # Track rewards at each step

obs, _ = env.reset()
done = False
step = 0

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    frame = env.render()

    frames_actual.append(Image.fromarray(frame))
    rewards.append(reward)

    step += 1

# Save trajectory as GIF
actual_gif_path = "actual_trajectory.gif"
frames_actual[0].save(
    actual_gif_path,
    save_all=True,
    append_images=frames_actual[1:],
    duration=100,
    loop=0
)

print(f"✅ Actual Agent Trajectory Saved: {actual_gif_path}")

# Plot the reward graph
plt.figure(figsize=(10, 4))
plt.plot(rewards, marker='o', linestyle='-', color='blue')
plt.title("Reward per Step (Actual Agent)")
plt.xlabel("Step")
plt.ylabel("Reward")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ✅ Actual Agent Trajectory Saved: actual_trajectory.gif

# %% [markdown]
# # **Generate Counterfactual Agent Trajectory GIF**

# %%
frames_random = []
obs, _ = env.reset()
done = False
while not done:
    action = env.action_space.sample()  # Random action
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    frame = env.render()
    frames_random.append(Image.fromarray(frame))

random_gif_path = "random_trajectory.gif"
frames_random[0].save(
    random_gif_path,
    save_all=True,
    append_images=frames_random[1:],
    duration=100,
    loop=0
)
print(f"✅ Counterfactual Agent Trajectory Saved: {random_gif_path}")
# Out:
# ✅ Random Agent Trajectory Saved: random_trajectory.gif

# %% [markdown]
# # **Counterfactual Trajactory**

# %%
print("🎲 Counterfactual Agent Trajectory:")
display(IPImage(filename=random_gif_path))
# Out:
# 🎲 Counterfactual Agent Trajectory:

# %%
import matplotlib.pyplot as plt

# Random agent trajectory and reward collection
frames_random = []
rewards_random = []

obs, _ = env.reset()
done = False

while not done:
    action = env.action_space.sample()  # Random action
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    frame = env.render()

    frames_random.append(Image.fromarray(frame))
    rewards_random.append(reward)

# Save the random agent trajectory as a GIF
random_gif_path = "random_trajectory.gif"
frames_random[0].save(
    random_gif_path,
    save_all=True,
    append_images=frames_random[1:],
    duration=100,
    loop=0
)
print(f"✅ Counterfactual Agent Trajectory Saved: {random_gif_path}")

# Plot reward per step for the random agent
plt.figure(figsize=(10, 4))
plt.plot(rewards_random, marker='x', linestyle='-', color='red')
plt.title("Reward per Step (Counterfactual Agent)")
plt.xlabel("Step")
plt.ylabel("Reward")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ✅ Random Agent Trajectory Saved: random_trajectory.gif

# %%
import matplotlib.pyplot as plt

# Ensure both reward lists exist: rewards (trained), rewards_random (random)
plt.figure(figsize=(12, 5))

# Plot trained agent
plt.plot(rewards, label="Trained Agent", color="blue", marker='o', linestyle='-')

# Plot random agent
plt.plot(rewards_random, label="Counterfactual Agent", color="red", marker='x', linestyle='--')

# Add titles and labels
plt.title("Reward per Step: Trained Agent vs Counterfactual Agent")
plt.xlabel("Step")
plt.ylabel("Reward")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# -----------------------------
# 1. Install Required Packages
# -----------------------------
# !pip install highway-env stable-baselines3[extra] --quiet

# -----------------------------
# 2. Imports
# -----------------------------
import gymnasium as gym
import highway_env
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import DQN
import os
from PIL import Image
from IPython.display import display, Image as IPImage

# -----------------------------
# 3. Environment Configuration
# -----------------------------
config = {
    "lanes_count": 4,
    "vehicles_count": 30,
    "duration": 40,
    "other_vehicles_type": "highway_env.vehicle.behavior.IDMVehicle",
    "screen_width": 600,
    "screen_height": 150,
    "centering_position": [0.3, 0.5],
    "scaling": 5.5,
    "simulation_frequency": 15,
    "policy_frequency": 5,
    "render_agent": True,
    "offscreen_rendering": True
}

env = gym.make("highway-v0", render_mode="rgb_array", config=config)
obs, _ = env.reset()

# -----------------------------
# 4. Train DQN Agent
# -----------------------------
model = DQN(
    "MlpPolicy",
    env,
    policy_kwargs={"net_arch": [256, 256]},
    verbose=1,
    learning_rate=5e-4,
    buffer_size=10000,
    learning_starts=100,
    batch_size=32,
    gamma=0.8,
    train_freq=1,
    target_update_interval=50,
)

model.learn(total_timesteps=500)
model.save("dqn_highway_model")

# -----------------------------
# 5. Generate Actual Agent Trajectory GIF
# -----------------------------
frames_actual = []
obs, _ = env.reset()
done = False
while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    frame = env.render()
    frames_actual.append(Image.fromarray(frame))

actual_gif_path = "actual_trajectory.gif"
frames_actual[0].save(
    actual_gif_path,
    save_all=True,
    append_images=frames_actual[1:],
    duration=100,
    loop=0
)
print(f"✅ Actual Agent Trajectory Saved: {actual_gif_path}")

# -----------------------------
# 6. Generate Random Agent Trajectory GIF
# -----------------------------
frames_random = []
obs, _ = env.reset()
done = False
while not done:
    action = env.action_space.sample()  # Random action
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    frame = env.render()
    frames_random.append(Image.fromarray(frame))

random_gif_path = "random_trajectory.gif"
frames_random[0].save(
    random_gif_path,
    save_all=True,
    append_images=frames_random[1:],
    duration=100,
    loop=0
)
print(f"✅ Random Agent Trajectory Saved: {random_gif_path}")

# -----------------------------
# 7. Display Both GIFs Inline
# -----------------------------
print("🎯 Actual Agent Trajectory:")
display(IPImage(filename=actual_gif_path))

print("🎲 Random Agent Trajectory:")
display(IPImage(filename=random_gif_path))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43       |
# |    ep_rew_mean      | 37       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 25       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 172      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0611   |
# |    n_updates        | 71       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 52       |
# |    ep_rew_mean      | 47.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 24       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 416      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00768  |
# |    n_updates        | 315      |
# ----------------------------------
# ✅ Actual Agent Trajectory Saved: actual_trajectory.gif
# ✅ Random Agent Trajectory Saved: random_trajectory.gif
# 🎯 Actual Agent Trajectory:
# 🎲 Random Agent Trajectory:
